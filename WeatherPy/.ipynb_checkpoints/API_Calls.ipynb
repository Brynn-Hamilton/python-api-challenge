# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "Resources/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 643

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# url = "api.openweathermap.org/data/2.5/weather?q={city name}&appid={weather_api_key}".format(weather_api_key = weather_api_key)
cities_pd = pd.DataFrame(columns = ["City", "Lat", "Lng", "Max Temp", "Humidity", 
                                    "Cloudiness", "Wind Speed", "Country", "Date"], index = cities)
cities_pd.index.name = "City"

for x in range(len(cities)):
        url = f"https://api.openweathermap.org/data/2.5/weather?q={cities[x]}&appid={weather_api_key}"
        response = requests.get(url)
        data = response.json()
        # if response.status_code == 200:
        try:
            #cities_pd.loc[cities[x]] = [cities[x], "City": cities[x], "Lat": data['coord']['lat'],
                             # "Lng": data['coord']['lon'], "Max Temp": data['main']['temp_max'],
                              #"Humidity": data['main']['humidity'], "Cloudiness": data['clouds']['all'],
                              #"Wind Speed": data['wind']['speed'], "Country": data['sys']['country'],
                              #"Date": data['dt']}, ignore_index= True)
            cities_pd.loc[cities[x]] = [cities[x], data['coord']['lat'],
                              data['coord']['lon'], data['main']['temp_max'],
                              data['main']['humidity'], data['clouds']['all'],
                              data['wind']['speed'], data['sys']['country'],
                              data['dt']]
            print (f"Processing City #{x + 1}. City Name: {cities[x]}")
        #else:
        except:
            cities_pd = cities_pd.drop(index = cities[x])
            print ("City information unavailable. Skipping...")
# Out:
# Processing City #1. City Name: rikitea
# Processing City #2. City Name: kapaa
# Processing City #3. City Name: tanggu
# Processing City #4. City Name: turukhansk
# City information unavailable. Skipping...
# Processing City #6. City Name: ushuaia
# Processing City #7. City Name: saskylakh
# Processing City #8. City Name: hallein
# Processing City #9. City Name: kodiak
# Processing City #10. City Name: port moresby
# Processing City #11. City Name: darhan
# Processing City #12. City Name: srednekolymsk
# Processing City #13. City Name: katsuura
# Processing City #14. City Name: narsaq
# Processing City #15. City Name: albany
# Processing City #16. City Name: busselton
# City information unavailable. Skipping...
# Processing City #18. City Name: oranjemund
# Processing City #19. City Name: cape town
# Processing City #20. City Name: punta arenas
# Processing City #21. City Name: beitbridge
# Processing City #22. City Name: raudeberg
# City information unavailable. Skipping...
# Processing City #24. City Name: medicine hat
# Processing City #25. City Name: port elizabeth
# Processing City #26. City Name: bredasdorp
# Processing City #27. City Name: ordu
# Processing City #28. City Name: garzon
# Processing City #29. City Name: natal
# Processing City #30. City Name: mount darwin
# Processing City #31. City Name: constitucion
# Processing City #32. City Name: ribeira grande
# Processing City #33. City Name: nouadhibou
# Processing City #34. City Name: mataura
# Processing City #35. City Name: avarua
# Processing City #36. City Name: ostrovnoy
# Processing City #37. City Name: kysyl-syr
# Processing City #38. City Name: tasiilaq
# Processing City #39. City Name: emba
# Processing City #40. City Name: bethel
# Processing City #41. City Name: hermanus
# Processing City #42. City Name: ponta do sol
# Processing City #43. City Name: anadyr
# Processing City #44. City Name: dikson
# City information unavailable. Skipping...
# Processing City #46. City Name: sorland
# Processing City #47. City Name: nhulunbuy
# Processing City #48. City Name: hope
# Processing City #49. City Name: saint george
# Processing City #50. City Name: new norfolk
# Processing City #51. City Name: mar del plata
# Processing City #52. City Name: warangal
# Processing City #53. City Name: hobart
# Processing City #54. City Name: rocha
# Processing City #55. City Name: amahai
# Processing City #56. City Name: sosnovo-ozerskoye
# Processing City #57. City Name: sinjar
# Processing City #58. City Name: nome
# Processing City #59. City Name: holme
# Processing City #60. City Name: dauphin
# Processing City #61. City Name: macau
# Processing City #62. City Name: juneau
# Processing City #63. City Name: college
# Processing City #64. City Name: longyearbyen
# Processing City #65. City Name: hami
# Processing City #66. City Name: plettenberg bay
# City information unavailable. Skipping...
# Processing City #68. City Name: saldanha
# Processing City #69. City Name: pudozh
# Processing City #70. City Name: blackwater
# Processing City #71. City Name: bassar
# Processing City #72. City Name: xichang
# Processing City #73. City Name: lagos
# Processing City #74. City Name: mehamn
# Processing City #75. City Name: juegang
# Processing City #76. City Name: puerto escondido
# City information unavailable. Skipping...
# Processing City #78. City Name: lebu
# Processing City #79. City Name: atuona
# Processing City #80. City Name: castro
# Processing City #81. City Name: hilo
# Processing City #82. City Name: merced
# Processing City #83. City Name: bluff
# Processing City #84. City Name: nikolskoye
# Processing City #85. City Name: sao filipe
# Processing City #86. City Name: japura
# Processing City #87. City Name: lanivtsi
# City information unavailable. Skipping...
# Processing City #89. City Name: kirakira
# Processing City #90. City Name: coquimbo
# Processing City #91. City Name: saint-philippe
# Processing City #92. City Name: ust-koksa
# Processing City #93. City Name: tabou
# Processing City #94. City Name: mackay
# Processing City #95. City Name: akyab
# Processing City #96. City Name: ahipara
# Processing City #97. City Name: tukrah
# Processing City #98. City Name: saint anthony
# City information unavailable. Skipping...
# Processing City #100. City Name: terrace
# Processing City #101. City Name: cancun
# Processing City #102. City Name: troitsk
# Processing City #103. City Name: vaini
# Processing City #104. City Name: airai
# Processing City #105. City Name: tura
# Processing City #106. City Name: porto recanati
# Processing City #107. City Name: rio gallegos
# Processing City #108. City Name: ancud
# Processing City #109. City Name: victoria
# Processing City #110. City Name: vaitape
# Processing City #111. City Name: gornopravdinsk
# Processing City #112. City Name: bolokhovo
# City information unavailable. Skipping...
# Processing City #114. City Name: tuktoyaktuk
# Processing City #115. City Name: yellowknife
# City information unavailable. Skipping...
# Processing City #117. City Name: carnarvon
# Processing City #118. City Name: pangkalanbuun
# City information unavailable. Skipping...
# Processing City #120. City Name: soyo
# City information unavailable. Skipping...
# Processing City #122. City Name: norman wells
# Processing City #123. City Name: ballina
# Processing City #124. City Name: barra do garcas
# Processing City #125. City Name: marsa matruh
# Processing City #126. City Name: southbridge
# Processing City #127. City Name: guerrero negro
# Processing City #128. City Name: butaritari
# Processing City #129. City Name: tual
# Processing City #130. City Name: port alfred
# Processing City #131. City Name: qom
# Processing City #132. City Name: hithadhoo
# Processing City #133. City Name: kinablangan
# Processing City #134. City Name: nizhniy tsasuchey
# Processing City #135. City Name: ponta delgada
# Processing City #136. City Name: bay roberts
# Processing City #137. City Name: abeokuta
# Processing City #138. City Name: east london
# Processing City #139. City Name: praxedis guerrero
# Processing City #140. City Name: araouane
# Processing City #141. City Name: jamestown
# City information unavailable. Skipping...
# Processing City #143. City Name: baker city
# Processing City #144. City Name: lompoc
# Processing City #145. City Name: poum
# Processing City #146. City Name: srandakan
# Processing City #147. City Name: alyangula
# Processing City #148. City Name: georgetown
# Processing City #149. City Name: puerto ayora
# Processing City #150. City Name: san patricio
# Processing City #151. City Name: cidreira
# City information unavailable. Skipping...
# Processing City #153. City Name: nurobod
# Processing City #154. City Name: cabo san lucas
# Processing City #155. City Name: faanui
# Processing City #156. City Name: boyolangu
# Processing City #157. City Name: kurilsk
# Processing City #158. City Name: mahebourg
# Processing City #159. City Name: sept-iles
# Processing City #160. City Name: makakilo city
# Processing City #161. City Name: leningradskiy
# Processing City #162. City Name: strathpeffer
# Processing City #163. City Name: klaksvik
# Processing City #164. City Name: camacha
# Processing City #165. City Name: maungaturoto
# Processing City #166. City Name: pasighat
# Processing City #167. City Name: pacifica
# City information unavailable. Skipping...
# Processing City #169. City Name: bathsheba
# Processing City #170. City Name: fenoarivo
# Processing City #171. City Name: kahului
# Processing City #172. City Name: ahuimanu
# Processing City #173. City Name: nha trang
# Processing City #174. City Name: port macquarie
# Processing City #175. City Name: el alto
# Processing City #176. City Name: barrow
# Processing City #177. City Name: khatanga
# Processing City #178. City Name: cayenne
# Processing City #179. City Name: gazli
# Processing City #180. City Name: chokurdakh
# Processing City #181. City Name: shar
# Processing City #182. City Name: severo-kurilsk
# Processing City #183. City Name: pokhara
# Processing City #184. City Name: innisfail
# Processing City #185. City Name: bambous virieux
# City information unavailable. Skipping...
# Processing City #187. City Name: merauke
# Processing City #188. City Name: frankfort
# Processing City #189. City Name: tiarei
# Processing City #190. City Name: tilichiki
# City information unavailable. Skipping...
# City information unavailable. Skipping...
# Processing City #193. City Name: surt
# Processing City #194. City Name: hualmay
# Processing City #195. City Name: barcelos
# Processing City #196. City Name: kruisfontein
# Processing City #197. City Name: fare
# Processing City #198. City Name: buala
# Processing City #199. City Name: marion
# Processing City #200. City Name: vila velha
# Processing City #201. City Name: bardiyah
# Processing City #202. City Name: miri
# Processing City #203. City Name: pout
# Processing City #204. City Name: akcakoca
# Processing City #205. City Name: san cristobal
# Processing City #206. City Name: octeville
# City information unavailable. Skipping...
# Processing City #208. City Name: jibuti
# Processing City #209. City Name: coihaique
# Processing City #210. City Name: ust-nera
# Processing City #211. City Name: kamir
# Processing City #212. City Name: scottsboro
# Processing City #213. City Name: powell
# Processing City #214. City Name: westport
# Processing City #215. City Name: conde
# Processing City #216. City Name: filadelfia
# City information unavailable. Skipping...
# Processing City #218. City Name: ko samui
# Processing City #219. City Name: beringovskiy
# Processing City #220. City Name: seoul
# Processing City #221. City Name: aracatuba
# Processing City #222. City Name: talnakh
# Processing City #223. City Name: junin
# City information unavailable. Skipping...
# Processing City #225. City Name: russell
# Processing City #226. City Name: paamiut
# Processing City #227. City Name: arraial do cabo
# City information unavailable. Skipping...
# Processing City #229. City Name: mezhdurechensk
# Processing City #230. City Name: isangel
# Processing City #231. City Name: rioja
# Processing City #232. City Name: raychikhinsk
# Processing City #233. City Name: wajima
# Processing City #234. City Name: kaitangata
# Processing City #235. City Name: te anau
# Processing City #236. City Name: rosa zarate
# Processing City #237. City Name: dunda
# Processing City #238. City Name: qaanaaq
# Processing City #239. City Name: sovetskaya gavan
# City information unavailable. Skipping...
# Processing City #241. City Name: fortuna
# Processing City #242. City Name: sebring
# Processing City #243. City Name: leh
# Processing City #244. City Name: vila franca do campo
# City information unavailable. Skipping...
# Processing City #246. City Name: sibolga
# Processing City #247. City Name: esperance
# Processing City #248. City Name: manavgat
# Processing City #249. City Name: anloga
# Processing City #250. City Name: sakaiminato
# Processing City #251. City Name: tieli
# Processing City #252. City Name: bandrele
# Processing City #253. City Name: karabash
# Processing City #254. City Name: mitsamiouli
# Processing City #255. City Name: bacolod
# Processing City #256. City Name: kupang
# Processing City #257. City Name: singaraja
# Processing City #258. City Name: safranbolu
# Processing City #259. City Name: matay
# Processing City #260. City Name: tabligbo
# Processing City #261. City Name: lixourion
# City information unavailable. Skipping...
# Processing City #263. City Name: pitimbu
# Processing City #264. City Name: bonfim
# Processing City #265. City Name: payo
# Processing City #266. City Name: tommot
# Processing City #267. City Name: kuito
# City information unavailable. Skipping...
# Processing City #269. City Name: staraya toropa
# Processing City #270. City Name: urucara
# Processing City #271. City Name: chadan
# Processing City #272. City Name: jieshi
# Processing City #273. City Name: najran
# Processing City #274. City Name: olga
# Processing City #275. City Name: kuryk
# City information unavailable. Skipping...
# Processing City #277. City Name: petrovsk-zabaykalskiy
# Processing City #278. City Name: havoysund
# Processing City #279. City Name: bumba
# Processing City #280. City Name: tigzirt
# Processing City #281. City Name: batagay-alyta
# Processing City #282. City Name: salalah
# Processing City #283. City Name: ulaanbaatar
# Processing City #284. City Name: northam
# City information unavailable. Skipping...
# Processing City #286. City Name: caravelas
# Processing City #287. City Name: santa marta
# Processing City #288. City Name: asau
# Processing City #289. City Name: tecpan
# Processing City #290. City Name: that phanom
# Processing City #291. City Name: abaza
# Processing City #292. City Name: kavieng
# Processing City #293. City Name: sfantu gheorghe
# Processing City #294. City Name: kiama
# Processing City #295. City Name: katherine
# Processing City #296. City Name: zhigansk
# City information unavailable. Skipping...
# Processing City #298. City Name: sao jose da coroa grande
# Processing City #299. City Name: vieux fort
# Processing City #300. City Name: blagoyevo
# Processing City #301. City Name: saint-joseph
# Processing City #302. City Name: hervey bay
# Processing City #303. City Name: waddan
# Processing City #304. City Name: yongan
# Processing City #305. City Name: axim
# Processing City #306. City Name: kiri buru
# Processing City #307. City Name: verkhoyansk
# Processing City #308. City Name: san rafael del sur
# Processing City #309. City Name: paita
# Processing City #310. City Name: netanya
# Processing City #311. City Name: keetmanshoop
# Processing City #312. City Name: akureyri
# Processing City #313. City Name: pangody
# Processing City #314. City Name: upernavik
# Processing City #315. City Name: riyadh
# Processing City #316. City Name: alofi
# Processing City #317. City Name: lagoa
# Processing City #318. City Name: turayf
# Processing City #319. City Name: maragogi
# Processing City #320. City Name: charters towers
# Processing City #321. City Name: cherskiy
# Processing City #322. City Name: kanker
# Processing City #323. City Name: doha
# Processing City #324. City Name: byron bay
# Processing City #325. City Name: pangnirtung
# Processing City #326. City Name: khash
# Processing City #327. City Name: samana
# Processing City #328. City Name: alice springs
# Processing City #329. City Name: korla
# Processing City #330. City Name: eura
# Processing City #331. City Name: pemba
# Processing City #332. City Name: clinton
# Processing City #333. City Name: touros
# Processing City #334. City Name: gobabis
# Processing City #335. City Name: grand bend
# Processing City #336. City Name: lasa
# Processing City #337. City Name: ontario
# Processing City #338. City Name: olinda
# Processing City #339. City Name: dori
# Processing City #340. City Name: champerico
# Processing City #341. City Name: xinyang
# Processing City #342. City Name: trier
# Processing City #343. City Name: aklavik
# City information unavailable. Skipping...
# Processing City #345. City Name: garowe
# Processing City #346. City Name: inuvik
# Processing City #347. City Name: clyde river
# City information unavailable. Skipping...
# City information unavailable. Skipping...
# Processing City #350. City Name: keti bandar
# Processing City #351. City Name: soe
# Processing City #352. City Name: broome
# Processing City #353. City Name: smirnykh
# Processing City #354. City Name: usinsk
# City information unavailable. Skipping...
# Processing City #356. City Name: torbay
# Processing City #357. City Name: watertown
# Processing City #358. City Name: bubaque
# Processing City #359. City Name: banjarmasin
# Processing City #360. City Name: niesky
# Processing City #361. City Name: waingapu
# Processing City #362. City Name: praia da vitoria
# Processing City #363. City Name: geraldton
# Processing City #364. City Name: wanning
# Processing City #365. City Name: pandan
# Processing City #366. City Name: seymchan
# Processing City #367. City Name: ilulissat
# Processing City #368. City Name: san quintin
# Processing City #369. City Name: thompson
# Processing City #370. City Name: chuy
# Processing City #371. City Name: half moon bay
# Processing City #372. City Name: malakal
# Processing City #373. City Name: iqaluit
# Processing City #374. City Name: aykhal
# Processing City #375. City Name: harper
# Processing City #376. City Name: olafsvik
# Processing City #377. City Name: tuatapere
# Processing City #378. City Name: turka
# Processing City #379. City Name: pacific grove
# Processing City #380. City Name: provideniya
# Processing City #381. City Name: koutsouras
# Processing City #382. City Name: kavaratti
# Processing City #383. City Name: cabimas
# Processing City #384. City Name: avera
# Processing City #385. City Name: sinnamary
# Processing City #386. City Name: weinan
# City information unavailable. Skipping...
# Processing City #388. City Name: hambantota
# Processing City #389. City Name: goure
# Processing City #390. City Name: tiksi
# Processing City #391. City Name: damietta
# Processing City #392. City Name: mersing
# Processing City #393. City Name: skelleftea
# City information unavailable. Skipping...
# Processing City #395. City Name: sangar
# Processing City #396. City Name: ossora
# Processing City #397. City Name: borovoy
# Processing City #398. City Name: waipawa
# City information unavailable. Skipping...
# Processing City #400. City Name: tamale
# Processing City #401. City Name: chimbote
# Processing City #402. City Name: saint augustine
# Processing City #403. City Name: nishihara
# Processing City #404. City Name: bengkulu
# Processing City #405. City Name: krasnogorsk
# Processing City #406. City Name: khonsa
# Processing City #407. City Name: matara
# Processing City #408. City Name: morehead
# Processing City #409. City Name: pallasovka
# Processing City #410. City Name: kushiro
# Processing City #411. City Name: mocuba
# Processing City #412. City Name: minab
# Processing City #413. City Name: nanae
# Processing City #414. City Name: komsomolskiy
# Processing City #415. City Name: shubarshi
# Processing City #416. City Name: hearst
# Processing City #417. City Name: sakakah
# Processing City #418. City Name: moose factory
# Processing City #419. City Name: santa maria
# Processing City #420. City Name: syamzha
# Processing City #421. City Name: tema
# Processing City #422. City Name: achalpur
# Processing City #423. City Name: dossor
# Processing City #424. City Name: fairbanks
# Processing City #425. City Name: el bagre
# Processing City #426. City Name: egvekinot
# Processing City #427. City Name: lo arado
# Processing City #428. City Name: bonavista
# Processing City #429. City Name: tucurui
# Processing City #430. City Name: brigantine
# Processing City #431. City Name: vila
# Processing City #432. City Name: matagami
# Processing City #433. City Name: duzce
# Processing City #434. City Name: onega
# Processing City #435. City Name: xining
# Processing City #436. City Name: vestmannaeyjar
# Processing City #437. City Name: moron
# Processing City #438. City Name: itaituba
# Processing City #439. City Name: sakete
# Processing City #440. City Name: batticaloa
# Processing City #441. City Name: roma
# Processing City #442. City Name: amapa
# Processing City #443. City Name: viedma
# Processing City #444. City Name: dunedin
# Processing City #445. City Name: petropavlovsk-kamchatskiy
# Processing City #446. City Name: acajutla
# Processing City #447. City Name: raymondville
# Processing City #448. City Name: rawson
# Processing City #449. City Name: kalmunai
# Processing City #450. City Name: ratnagiri
# Processing City #451. City Name: superior
# Processing City #452. City Name: launceston
# Processing City #453. City Name: maxixe
# Processing City #454. City Name: nemuro
# Processing City #455. City Name: san jose
# Processing City #456. City Name: sola
# Processing City #457. City Name: mount gambier
# Processing City #458. City Name: banda aceh
# Processing City #459. City Name: verkhnevilyuysk
# Processing City #460. City Name: pangoa
# Processing City #461. City Name: huanan
# Processing City #462. City Name: evensk
# Processing City #463. City Name: dzhebariki-khaya
# Processing City #464. City Name: izberbash
# Processing City #465. City Name: margate
# Processing City #466. City Name: grindavik
# Processing City #467. City Name: marsh harbour
# Processing City #468. City Name: bandarban
# Processing City #469. City Name: richards bay
# Processing City #470. City Name: wadena
# City information unavailable. Skipping...
# Processing City #472. City Name: kilrush
# Processing City #473. City Name: casper
# Processing City #474. City Name: bontang
# Processing City #475. City Name: namibe
# Processing City #476. City Name: nanortalik
# Processing City #477. City Name: chapais
# Processing City #478. City Name: timra
# City information unavailable. Skipping...
# Processing City #480. City Name: laguna
# Processing City #481. City Name: berlevag
# Processing City #482. City Name: hanyang
# Processing City #483. City Name: hailar
# Processing City #484. City Name: novochernorechenskiy
# Processing City #485. City Name: tazovskiy
# Processing City #486. City Name: ligayan
# Processing City #487. City Name: show low
# City information unavailable. Skipping...
# Processing City #489. City Name: havre-saint-pierre
# Processing City #490. City Name: north bend
# Processing City #491. City Name: luba
# Processing City #492. City Name: kimbe
# Processing City #493. City Name: cozumel
# Processing City #494. City Name: cap malheureux
# Processing City #495. City Name: kipini
# City information unavailable. Skipping...
# Processing City #497. City Name: muros
# Processing City #498. City Name: coos bay
# Processing City #499. City Name: iskateley
# Processing City #500. City Name: hofn
# Processing City #501. City Name: souris
# City information unavailable. Skipping...
# City information unavailable. Skipping...
# Processing City #504. City Name: kendari
# Processing City #505. City Name: sulangan
# Processing City #506. City Name: biak
# Processing City #507. City Name: natitingou
# Processing City #508. City Name: sri aman
# Processing City #509. City Name: seddon
# City information unavailable. Skipping...
# Processing City #511. City Name: surgut
# Processing City #512. City Name: xingyi
# City information unavailable. Skipping...
# Processing City #514. City Name: paramonga
# Processing City #515. City Name: the valley
# Processing City #516. City Name: bhalki
# Processing City #517. City Name: brae
# Processing City #518. City Name: sao jose do belmonte
# Processing City #519. City Name: snezhnogorsk
# Processing City #520. City Name: kibaya
# Processing City #521. City Name: solnechnyy
# Processing City #522. City Name: haines junction
# Processing City #523. City Name: anshun
# Processing City #524. City Name: farkhor
# Processing City #525. City Name: kloulklubed
# Processing City #526. City Name: skjervoy
# Processing City #527. City Name: ixtapa
# Processing City #528. City Name: dawlatabad
# Processing City #529. City Name: sao joao da barra
# Processing City #530. City Name: otradnoye
# Processing City #531. City Name: tarko-sale
# Processing City #532. City Name: nieuw amsterdam
# Processing City #533. City Name: potosi
# Processing City #534. City Name: aksarka
# Processing City #535. City Name: auki
# Processing City #536. City Name: qaqortoq
# Processing City #537. City Name: lamu
# Processing City #538. City Name: carballo
# Processing City #539. City Name: tatarbunary
# City information unavailable. Skipping...
# Processing City #541. City Name: flinders
# Processing City #542. City Name: pahrump
# Processing City #543. City Name: ozernovskiy
# Processing City #544. City Name: laibin
# Processing City #545. City Name: bahia blanca
# Processing City #546. City Name: arlit
# Processing City #547. City Name: inskoy
# Processing City #548. City Name: trapani
# Processing City #549. City Name: kyzyl-suu
# Processing City #550. City Name: thinadhoo
# Processing City #551. City Name: mayo
# Processing City #552. City Name: standerton
# Processing City #553. City Name: sitka
# Processing City #554. City Name: hasaki
# Processing City #555. City Name: san ignacio
# Processing City #556. City Name: henties bay
# Processing City #557. City Name: basco
# Processing City #558. City Name: tselinnoye
# Processing City #559. City Name: abu samrah
# City information unavailable. Skipping...
# Processing City #561. City Name: podares
# Processing City #562. City Name: bukachacha
# Processing City #563. City Name: jablanica
# Processing City #564. City Name: uden
# Processing City #565. City Name: tornio
# Processing City #566. City Name: langxiang
# Processing City #567. City Name: astana
# Processing City #568. City Name: kisangani
# Processing City #569. City Name: la ronge
# Processing City #570. City Name: mormugao
# Processing City #571. City Name: port keats
# Processing City #572. City Name: pimentel
# Processing City #573. City Name: morondava
# Processing City #574. City Name: tres arroyos
# Processing City #575. City Name: pirapemas
# Processing City #576. City Name: port hedland
# Processing City #577. City Name: veraval
# Processing City #578. City Name: davila
# Processing City #579. City Name: pokrovka
# Processing City #580. City Name: bilaspur
# Processing City #581. City Name: buraydah
# City information unavailable. Skipping...
# Processing City #583. City Name: port hardy
# Processing City #584. City Name: carbondale
# Processing City #585. City Name: cavalcante
# Processing City #586. City Name: cururupu
# Processing City #587. City Name: bowen
# Processing City #588. City Name: akdepe
# Processing City #589. City Name: guangyuan
# Processing City #590. City Name: ola
# Processing City #591. City Name: summerside
# Processing City #592. City Name: dudinka
# Processing City #593. City Name: aanekoski
# Processing City #594. City Name: roald
# Processing City #595. City Name: kroya
# Processing City #596. City Name: cuamba
# Processing City #597. City Name: souillac
# Processing City #598. City Name: nuoro
# Processing City #599. City Name: kolpny
# Processing City #600. City Name: keta
# Processing City #601. City Name: tamandare
# Processing City #602. City Name: qui nhon
# Processing City #603. City Name: tocopilla
# City information unavailable. Skipping...
# Processing City #605. City Name: sao felipe
# Processing City #606. City Name: synya
# Processing City #607. City Name: asfi
# Processing City #608. City Name: spearfish
# Processing City #609. City Name: bintulu
# Processing City #610. City Name: sirjan
# Processing City #611. City Name: krasnoselkup
# Processing City #612. City Name: mezinovskiy
# Processing City #613. City Name: ankang
# Processing City #614. City Name: omsukchan
# Processing City #615. City Name: los llanos de aridane
# Processing City #616. City Name: pochutla
# City information unavailable. Skipping...
# Processing City #618. City Name: gorno-altaysk
# Processing City #619. City Name: sisimiut
# Processing City #620. City Name: yanam
# Processing City #621. City Name: along
# City information unavailable. Skipping...
# Processing City #623. City Name: caririacu
# Processing City #624. City Name: naze
# Processing City #625. City Name: durban
# Processing City #626. City Name: nicolas bravo
# Processing City #627. City Name: kenai
# City information unavailable. Skipping...
# Processing City #629. City Name: araxa
# Processing City #630. City Name: tongliao
# Processing City #631. City Name: teguise
# Processing City #632. City Name: price
# Processing City #633. City Name: pritzwalk
# Processing City #634. City Name: tateyama
# Processing City #635. City Name: kontagora
# Processing City #636. City Name: yarovoye
# Processing City #637. City Name: puno
# Processing City #638. City Name: elizabeth city
# Processing City #639. City Name: nalut
# Processing City #640. City Name: labuhan
# Processing City #641. City Name: deputatskiy
# Processing City #642. City Name: orange cove
# Processing City #643. City Name: urumqi

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_pd.to_csv("Weather_Output_Final.csv")

# %%
cities_pd = cities_pd.reset_index(drop = True)
cities_pd
# Out:
#             City    Lat     Lng Max Temp Humidity Cloudiness Wind Speed  \
# 0        rikitea -23.12 -134.97   296.16       84        100       5.68
# 1          kapaa  22.08 -159.32   303.71       78         40        3.1
# 2         tanggu  39.02  117.65   298.15       83         83          1
# 3     turukhansk  65.82   87.98   280.03       93         35       3.26
# 4        ushuaia  -54.8   -68.3   271.15       92         53        2.1
# ..           ...    ...     ...      ...      ...        ...        ...
# 587        nalut  30.33   10.85   303.19       39          0       7.85
# 588      labuhan  -6.88  112.21   297.55       83          9       5.29
# 589  deputatskiy   69.3   139.9   279.68       66         56       3.27
# 590  orange cove  36.62 -119.31   306.48       31          1       1.78
# 591       urumqi   43.8    87.6   300.15       30          0          5
#
#     Country        Date
# 0        PF  1595017856
# 1        US  1595017857
# 2        CN  1595017857
# 3        RU  1595017857
# 4        AR  1595017858
# ..      ...         ...
# 587      LY  1595018016
# 588      ID  1595018016
# 589      RU  1595018016
# 590      US  1595018017
# 591      CN  1595018017
#
# [592 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
cities_pd = cities_pd.reset_index(drop = True)
cities_pd.drop(columns = ["City", "Country", "Date"]).astype(float).describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed
# count  592.000000  592.000000  592.000000  592.000000  592.000000  592.000000
# mean    22.171115   21.246774  293.856182   71.858108   47.611486    3.493294
# std     32.761439   90.953302    8.135416   21.119116   38.427479    2.333291
# min    -54.800000 -179.170000  271.150000    9.000000    0.000000    0.220000
# 25%     -5.225000  -59.627500  287.545000   62.000000    5.000000    1.787500
# 50%     28.300000   27.070000  295.105000   77.000000   40.000000    3.100000
# 75%     49.622500  103.025000  299.582500   87.250000   89.250000    4.600000
# max     78.220000  179.320000  313.710000  100.000000  100.000000   15.050000

# %%
#  Get the indices of cities that have humidity over 100%.
excess_humidity = cities_pd[cities_pd["Humidity"] > 100].index.tolist()
excess_humidity
# Out:
# []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
cities_pd
# Out:
#             City    Lat     Lng Max Temp Humidity Cloudiness Wind Speed  \
# 0        rikitea -23.12 -134.97   296.16       84        100       5.68
# 1          kapaa  22.08 -159.32   303.71       78         40        3.1
# 2         tanggu  39.02  117.65   298.15       83         83          1
# 3     turukhansk  65.82   87.98   280.03       93         35       3.26
# 4        ushuaia  -54.8   -68.3   271.15       92         53        2.1
# ..           ...    ...     ...      ...      ...        ...        ...
# 587        nalut  30.33   10.85   303.19       39          0       7.85
# 588      labuhan  -6.88  112.21   297.55       83          9       5.29
# 589  deputatskiy   69.3   139.9   279.68       66         56       3.27
# 590  orange cove  36.62 -119.31   306.48       31          1       1.78
# 591       urumqi   43.8    87.6   300.15       30          0          5
#
#     Country        Date
# 0        PF  1595017856
# 1        US  1595017857
# 2        CN  1595017857
# 3        RU  1595017857
# 4        AR  1595017858
# ..      ...         ...
# 587      LY  1595018016
# 588      ID  1595018016
# 589      RU  1595018016
# 590      US  1595018017
# 591      CN  1595018017
#
# [592 rows x 9 columns]

# %%
# Extract relevant fields from the data frame
clean_city_data = cities_pd.drop(columns = ["City", "Lng", "Country", "Date"])


# Export the City_Data into a csv
clean_city_data.to_csv("Weather_Output_Plot_Data.csv")
clean_city_data
# Out:
#        Lat Max Temp Humidity Cloudiness Wind Speed
# 0   -23.12   296.16       84        100       5.68
# 1    22.08   303.71       78         40        3.1
# 2    39.02   298.15       83         83          1
# 3    65.82   280.03       93         35       3.26
# 4    -54.8   271.15       92         53        2.1
# ..     ...      ...      ...        ...        ...
# 587  30.33   303.19       39          0       7.85
# 588  -6.88   297.55       83          9       5.29
# 589   69.3   279.68       66         56       3.27
# 590  36.62   306.48       31          1       1.78
# 591   43.8   300.15       30          0          5
#
# [592 rows x 5 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_values = clean_city_data['Lat']
y_values = clean_city_data['Max Temp']
plt.scatter(x_values, y_values)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title("City Latitude vs. Max Temperature 7/17/2020")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_values = clean_city_data['Lat']
y_values = clean_city_data['Humidity']
plt.scatter(x_values, y_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title("City Latitude vs. Humidity 7/17/2020")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_values = clean_city_data['Lat']
y_values = clean_city_data['Cloudiness']
plt.scatter(x_values, y_values)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (F)')
plt.title("City Latitude vs. Cloudiness 7/17/2020")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_values = clean_city_data['Lat']
y_values = clean_city_data['Wind Speed']
plt.scatter(x_values, y_values)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title("City Latitude vs. Wind Speed 7/17/2020")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.8271188905041935

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.39936284758885965

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.10829462153873139

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.0008996079328825663

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.05768812657005063

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.0684912094859049

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.023371104533850804

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.03381889207758188
